# %%
import torch
from transformers import AutoTokenizer, AutoModel
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Electra 모델 클래스
class ElectraVectorizer:
    def __init__(self, model_name):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModel.from_pretrained(model_name).to(self.device)

    def get_first_hidden_state(self, text):
        inputs = self.tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512).to(self.device)
        #tokens = vectorizer.tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
        #print("Tokens:", tokens)
        #print("Token IDs:", inputs['input_ids'][0])
        with torch.no_grad():
            outputs = self.model(**inputs)
            #print(outputs.last_hidden_state[0].size())
        return outputs.last_hidden_state[0][0].cpu().numpy()  # 첫 번째 hidden state 벡터를 사용

# %%
# 데이터 로드
books_df4 = pd.read_excel('/content/book_list_with_category_filtered.xlsx')  # 가사 데이터 로드
book_texts4 = books_df4['text'].tolist()

# 모델 초기화
model_name = "blue2959/koelectra-base-v3-discriminator-finetuned-kor-8-emotions_v1.4"
vectorizer = ElectraVectorizer(model_name)

# 도서 벡터 미리 계산하여 저장
book_vectors4 = [vectorizer.get_first_hidden_state(text) for text in book_texts4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-3e2c85882d5a> in <cell line: 3>()
#       1 # 데이터 로드
#       2 books_df4 = pd.read_excel('/content/book_list_with_category_filtered.xlsx')  # 가사 데이터 로드
# ----> 3 book_texts4 = books_df4['text'].tolist()
#       4
#       5 # 모델 초기화
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'text'

# %%
# 벡터 형태 출력
for i, vec in enumerate(book_vectors4):
    print(f"Vector {i} shape: {vec.shape}")
# Out:
# Vector 0 shape: (768,)
# Vector 1 shape: (768,)
# Vector 2 shape: (768,)
# Vector 3 shape: (768,)
# Vector 4 shape: (768,)
# Vector 5 shape: (768,)
# Vector 6 shape: (768,)
# Vector 7 shape: (768,)
# Vector 8 shape: (768,)
# Vector 9 shape: (768,)
# Vector 10 shape: (768,)
# Vector 11 shape: (768,)
# Vector 12 shape: (768,)
# Vector 13 shape: (768,)
# Vector 14 shape: (768,)
# Vector 15 shape: (768,)
# Vector 16 shape: (768,)
# Vector 17 shape: (768,)
# Vector 18 shape: (768,)
# Vector 19 shape: (768,)
# Vector 20 shape: (768,)
# Vector 21 shape: (768,)
# Vector 22 shape: (768,)
# Vector 23 shape: (768,)
# Vector 24 shape: (768,)
# Vector 25 shape: (768,)
# Vector 26 shape: (768,)
# Vector 27 shape: (768,)
# Vector 28 shape: (768,)
# Vector 29 shape: (768,)
# Vector 30 shape: (768,)
# Vector 31 shape: (768,)
# Vector 32 shape: (768,)
# Vector 33 shape: (768,)
# Vector 34 shape: (768,)
# Vector 35 shape: (768,)
# Vector 36 shape: (768,)
# Vector 37 shape: (768,)
# Vector 38 shape: (768,)
# Vector 39 shape: (768,)
# Vector 40 shape: (768,)
# Vector 41 shape: (768,)
# Vector 42 shape: (768,)
# Vector 43 shape: (768,)
# Vector 44 shape: (768,)
# Vector 45 shape: (768,)
# Vector 46 shape: (768,)
# Vector 47 shape: (768,)
# Vector 48 shape: (768,)
# Vector 49 shape: (768,)
# Vector 50 shape: (768,)
# Vector 51 shape: (768,)
# Vector 52 shape: (768,)
# Vector 53 shape: (768,)
# Vector 54 shape: (768,)
# Vector 55 shape: (768,)
# Vector 56 shape: (768,)
# Vector 57 shape: (768,)
# Vector 58 shape: (768,)
# Vector 59 shape: (768,)
# Vector 60 shape: (768,)
# Vector 61 shape: (768,)
# Vector 62 shape: (768,)
# Vector 63 shape: (768,)
# Vector 64 shape: (768,)
# Vector 65 shape: (768,)
# Vector 66 shape: (768,)
# Vector 67 shape: (768,)
# Vector 68 shape: (768,)
# Vector 69 shape: (768,)
# Vector 70 shape: (768,)
# Vector 71 shape: (768,)
# Vector 72 shape: (768,)
# Vector 73 shape: (768,)
# Vector 74 shape: (768,)
# Vector 75 shape: (768,)
# Vector 76 shape: (768,)
# Vector 77 shape: (768,)
# Vector 78 shape: (768,)
# Vector 79 shape: (768,)
# Vector 80 shape: (768,)
# Vector 81 shape: (768,)
# Vector 82 shape: (768,)
# Vector 83 shape: (768,)
# Vector 84 shape: (768,)
# Vector 85 shape: (768,)
# Vector 86 shape: (768,)
# Vector 87 shape: (768,)
# Vector 88 shape: (768,)
# Vector 89 shape: (768,)
# Vector 90 shape: (768,)
# Vector 91 shape: (768,)
# Vector 92 shape: (768,)
# Vector 93 shape: (768,)
# Vector 94 shape: (768,)
# Vector 95 shape: (768,)
# Vector 96 shape: (768,)
# Vector 97 shape: (768,)
# Vector 98 shape: (768,)
# Vector 99 shape: (768,)
# Vector 100 shape: (768,)
# Vector 101 shape: (768,)
# Vector 102 shape: (768,)
# Vector 103 shape: (768,)
# Vector 104 shape: (768,)
# Vector 105 shape: (768,)
# Vector 106 shape: (768,)
# Vector 107 shape: (768,)
# Vector 108 shape: (768,)
# Vector 109 shape: (768,)
# Vector 110 shape: (768,)
# Vector 111 shape: (768,)
# Vector 112 shape: (768,)
# Vector 113 shape: (768,)
# Vector 114 shape: (768,)
# Vector 115 shape: (768,)
# Vector 116 shape: (768,)
# Vector 117 shape: (768,)
# Vector 118 shape: (768,)
# Vector 119 shape: (768,)
# Vector 120 shape: (768,)
# Vector 121 shape: (768,)
# Vector 122 shape: (768,)
# Vector 123 shape: (768,)
# Vector 124 shape: (768,)
# Vector 125 shape: (768,)
# Vector 126 shape: (768,)
# Vector 127 shape: (768,)
# Vector 128 shape: (768,)
# Vector 129 shape: (768,)
# Vector 130 shape: (768,)
# Vector 131 shape: (768,)
# Vector 132 shape: (768,)
# Vector 133 shape: (768,)
# Vector 134 shape: (768,)
# Vector 135 shape: (768,)
# Vector 136 shape: (768,)
# Vector 137 shape: (768,)
# Vector 138 shape: (768,)
# Vector 139 shape: (768,)
# Vector 140 shape: (768,)
# Vector 141 shape: (768,)
# Vector 142 shape: (768,)
# Vector 143 shape: (768,)
# Vector 144 shape: (768,)
# Vector 145 shape: (768,)
# Vector 146 shape: (768,)
# Vector 147 shape: (768,)
# Vector 148 shape: (768,)
# Vector 149 shape: (768,)
# Vector 150 shape: (768,)
# Vector 151 shape: (768,)
# Vector 152 shape: (768,)
# Vector 153 shape: (768,)
# Vector 154 shape: (768,)
# Vector 155 shape: (768,)
# Vector 156 shape: (768,)
# Vector 157 shape: (768,)
# Vector 158 shape: (768,)
# Vector 159 shape: (768,)
# Vector 160 shape: (768,)
# Vector 161 shape: (768,)
# Vector 162 shape: (768,)
# Vector 163 shape: (768,)
# Vector 164 shape: (768,)
# Vector 165 shape: (768,)
# Vector 166 shape: (768,)
# Vector 167 shape: (768,)
# Vector 168 shape: (768,)
# Vector 169 shape: (768,)
# Vector 170 shape: (768,)
# Vector 171 shape: (768,)
# Vector 172 shape: (768,)
# Vector 173 shape: (768,)
# Vector 174 shape: (768,)
# Vector 175 shape: (768,)
# Vector 176 shape: (768,)
# Vector 177 shape: (768,)
# Vector 178 shape: (768,)
# Vector 179 shape: (768,)
# Vector 180 shape: (768,)
# Vector 181 shape: (768,)
# Vector 182 shape: (768,)
# Vector 183 shape: (768,)
# Vector 184 shape: (768,)
# Vector 185 shape: (768,)
# Vector 186 shape: (768,)
# Vector 187 shape: (768,)
# Vector 188 shape: (768,)
# Vector 189 shape: (768,)
# Vector 190 shape: (768,)
# Vector 191 shape: (768,)
# Vector 192 shape: (768,)
# Vector 193 shape: (768,)
# Vector 194 shape: (768,)
# Vector 195 shape: (768,)
# Vector 196 shape: (768,)
# Vector 197 shape: (768,)
# Vector 198 shape: (768,)
# Vector 199 shape: (768,)
# Vector 200 shape: (768,)
# Vector 201 shape: (768,)
# Vector 202 shape: (768,)
# Vector 203 shape: (768,)
# Vector 204 shape: (768,)
# Vector 205 shape: (768,)
# Vector 206 shape: (768,)
# Vector 207 shape: (768,)
# Vector 208 shape: (768,)
# Vector 209 shape: (768,)
# Vector 210 shape: (768,)
# Vector 211 shape: (768,)
# Vector 212 shape: (768,)
# Vector 213 shape: (768,)
# Vector 214 shape: (768,)
# Vector 215 shape: (768,)
# Vector 216 shape: (768,)
# Vector 217 shape: (768,)
# Vector 218 shape: (768,)
# Vector 219 shape: (768,)
# Vector 220 shape: (768,)
# Vector 221 shape: (768,)
# Vector 222 shape: (768,)
# Vector 223 shape: (768,)
# Vector 224 shape: (768,)
# Vector 225 shape: (768,)
# Vector 226 shape: (768,)
# Vector 227 shape: (768,)
# Vector 228 shape: (768,)
# Vector 229 shape: (768,)
# Vector 230 shape: (768,)
# Vector 231 shape: (768,)
# Vector 232 shape: (768,)
# Vector 233 shape: (768,)
# Vector 234 shape: (768,)
# Vector 235 shape: (768,)
# Vector 236 shape: (768,)
# Vector 237 shape: (768,)
# Vector 238 shape: (768,)
# Vector 239 shape: (768,)
# Vector 240 shape: (768,)
# Vector 241 shape: (768,)
# Vector 242 shape: (768,)
# Vector 243 shape: (768,)
# Vector 244 shape: (768,)
# Vector 245 shape: (768,)
# Vector 246 shape: (768,)
# Vector 247 shape: (768,)
# Vector 248 shape: (768,)
# Vector 249 shape: (768,)
# Vector 250 shape: (768,)
# Vector 251 shape: (768,)
# Vector 252 shape: (768,)
# Vector 253 shape: (768,)
# Vector 254 shape: (768,)
# Vector 255 shape: (768,)
# Vector 256 shape: (768,)
# Vector 257 shape: (768,)
# Vector 258 shape: (768,)
# Vector 259 shape: (768,)
# Vector 260 shape: (768,)
# Vector 261 shape: (768,)
# Vector 262 shape: (768,)
# Vector 263 shape: (768,)
# Vector 264 shape: (768,)
# Vector 265 shape: (768,)
# Vector 266 shape: (768,)
# Vector 267 shape: (768,)
# Vector 268 shape: (768,)
# Vector 269 shape: (768,)
# Vector 270 shape: (768,)
# Vector 271 shape: (768,)
# Vector 272 shape: (768,)
# Vector 273 shape: (768,)
# Vector 274 shape: (768,)
# Vector 275 shape: (768,)
# Vector 276 shape: (768,)
# Vector 277 shape: (768,)
# Vector 278 shape: (768,)
# Vector 279 shape: (768,)
# Vector 280 shape: (768,)
# Vector 281 shape: (768,)
# Vector 282 shape: (768,)
# Vector 283 shape: (768,)
# Vector 284 shape: (768,)
# Vector 285 shape: (768,)
# Vector 286 shape: (768,)
# Vector 287 shape: (768,)
# Vector 288 shape: (768,)
# Vector 289 shape: (768,)
# Vector 290 shape: (768,)
# Vector 291 shape: (768,)
# Vector 292 shape: (768,)
# Vector 293 shape: (768,)
# Vector 294 shape: (768,)
# Vector 295 shape: (768,)
# Vector 296 shape: (768,)
# Vector 297 shape: (768,)
# Vector 298 shape: (768,)
# Vector 299 shape: (768,)
# Vector 300 shape: (768,)
# Vector 301 shape: (768,)
# Vector 302 shape: (768,)
# Vector 303 shape: (768,)
# Vector 304 shape: (768,)
# Vector 305 shape: (768,)
# Vector 306 shape: (768,)
# Vector 307 shape: (768,)
# Vector 308 shape: (768,)
# Vector 309 shape: (768,)
# Vector 310 shape: (768,)
# Vector 311 shape: (768,)
# Vector 312 shape: (768,)
# Vector 313 shape: (768,)
# Vector 314 shape: (768,)
# Vector 315 shape: (768,)
# Vector 316 shape: (768,)
# Vector 317 shape: (768,)
# Vector 318 shape: (768,)
# Vector 319 shape: (768,)
# Vector 320 shape: (768,)
# Vector 321 shape: (768,)
# Vector 322 shape: (768,)
# Vector 323 shape: (768,)
# Vector 324 shape: (768,)
# Vector 325 shape: (768,)
# Vector 326 shape: (768,)
# Vector 327 shape: (768,)
# Vector 328 shape: (768,)
# Vector 329 shape: (768,)
# Vector 330 shape: (768,)
# Vector 331 shape: (768,)
# Vector 332 shape: (768,)
# Vector 333 shape: (768,)
# Vector 334 shape: (768,)
# Vector 335 shape: (768,)
# Vector 336 shape: (768,)
# Vector 337 shape: (768,)
# Vector 338 shape: (768,)
# Vector 339 shape: (768,)
# Vector 340 shape: (768,)
# Vector 341 shape: (768,)
# Vector 342 shape: (768,)
# Vector 343 shape: (768,)
# Vector 344 shape: (768,)
# Vector 345 shape: (768,)
# Vector 346 shape: (768,)
# Vector 347 shape: (768,)
# Vector 348 shape: (768,)
# Vector 349 shape: (768,)
# Vector 350 shape: (768,)
# Vector 351 shape: (768,)
# Vector 352 shape: (768,)
# Vector 353 shape: (768,)
# Vector 354 shape: (768,)
# Vector 355 shape: (768,)
# Vector 356 shape: (768,)
# Vector 357 shape: (768,)
# Vector 358 shape: (768,)
# Vector 359 shape: (768,)
# Vector 360 shape: (768,)
# Vector 361 shape: (768,)
# Vector 362 shape: (768,)
# Vector 363 shape: (768,)
# Vector 364 shape: (768,)
# Vector 365 shape: (768,)
# Vector 366 shape: (768,)
# Vector 367 shape: (768,)
# Vector 368 shape: (768,)
# Vector 369 shape: (768,)
# Vector 370 shape: (768,)
# Vector 371 shape: (768,)
# Vector 372 shape: (768,)
# Vector 373 shape: (768,)
# Vector 374 shape: (768,)
# Vector 375 shape: (768,)
# Vector 376 shape: (768,)
# Vector 377 shape: (768,)
# Vector 378 shape: (768,)
# Vector 379 shape: (768,)
# Vector 380 shape: (768,)
# Vector 381 shape: (768,)
# Vector 382 shape: (768,)
# Vector 383 shape: (768,)
# Vector 384 shape: (768,)
# Vector 385 shape: (768,)
# Vector 386 shape: (768,)
# Vector 387 shape: (768,)
# Vector 388 shape: (768,)
# Vector 389 shape: (768,)
# Vector 390 shape: (768,)
# Vector 391 shape: (768,)
# Vector 392 shape: (768,)
# Vector 393 shape: (768,)
# Vector 394 shape: (768,)
# Vector 395 shape: (768,)
# Vector 396 shape: (768,)
# Vector 397 shape: (768,)
# Vector 398 shape: (768,)
# Vector 399 shape: (768,)
# Vector 400 shape: (768,)
# Vector 401 shape: (768,)
# Vector 402 shape: (768,)
# Vector 403 shape: (768,)
# Vector 404 shape: (768,)
# Vector 405 shape: (768,)
# Vector 406 shape: (768,)
# Vector 407 shape: (768,)
# Vector 408 shape: (768,)
# Vector 409 shape: (768,)
# Vector 410 shape: (768,)
# Vector 411 shape: (768,)
# Vector 412 shape: (768,)
# Vector 413 shape: (768,)
# Vector 414 shape: (768,)
# Vector 415 shape: (768,)
# Vector 416 shape: (768,)
# Vector 417 shape: (768,)
# Vector 418 shape: (768,)
# Vector 419 shape: (768,)
# Vector 420 shape: (768,)
# Vector 421 shape: (768,)
# Vector 422 shape: (768,)
# Vector 423 shape: (768,)
# Vector 424 shape: (768,)
# Vector 425 shape: (768,)
# Vector 426 shape: (768,)
# Vector 427 shape: (768,)
# Vector 428 shape: (768,)
# Vector 429 shape: (768,)
# Vector 430 shape: (768,)
# Vector 431 shape: (768,)
# Vector 432 shape: (768,)
# Vector 433 shape: (768,)
# Vector 434 shape: (768,)
# Vector 435 shape: (768,)
# Vector 436 shape: (768,)
# Vector 437 shape: (768,)
# Vector 438 shape: (768,)
# Vector 439 shape: (768,)
# Vector 440 shape: (768,)
# Vector 441 shape: (768,)
# Vector 442 shape: (768,)
# Vector 443 shape: (768,)
# Vector 444 shape: (768,)
# Vector 445 shape: (768,)
# Vector 446 shape: (768,)
# Vector 447 shape: (768,)
# Vector 448 shape: (768,)
# Vector 449 shape: (768,)
# Vector 450 shape: (768,)
# Vector 451 shape: (768,)
# Vector 452 shape: (768,)
# Vector 453 shape: (768,)
# Vector 454 shape: (768,)
# Vector 455 shape: (768,)
# Vector 456 shape: (768,)
# Vector 457 shape: (768,)
# Vector 458 shape: (768,)
# Vector 459 shape: (768,)
# Vector 460 shape: (768,)
# Vector 461 shape: (768,)
# Vector 462 shape: (768,)
# Vector 463 shape: (768,)
# Vector 464 shape: (768,)
# Vector 465 shape: (768,)
# Vector 466 shape: (768,)
# Vector 467 shape: (768,)
# Vector 468 shape: (768,)
# Vector 469 shape: (768,)
# Vector 470 shape: (768,)
# Vector 471 shape: (768,)
# Vector 472 shape: (768,)
# Vector 473 shape: (768,)
# Vector 474 shape: (768,)
# Vector 475 shape: (768,)
# Vector 476 shape: (768,)
# Vector 477 shape: (768,)
# Vector 478 shape: (768,)
# Vector 479 shape: (768,)
# Vector 480 shape: (768,)
# Vector 481 shape: (768,)
# Vector 482 shape: (768,)
# Vector 483 shape: (768,)
# Vector 484 shape: (768,)
# Vector 485 shape: (768,)
# Vector 486 shape: (768,)
# Vector 487 shape: (768,)
# Vector 488 shape: (768,)
# Vector 489 shape: (768,)
# Vector 490 shape: (768,)
# Vector 491 shape: (768,)
# Vector 492 shape: (768,)
# Vector 493 shape: (768,)
# Vector 494 shape: (768,)
# Vector 495 shape: (768,)
# Vector 496 shape: (768,)
# Vector 497 shape: (768,)
# Vector 498 shape: (768,)
# Vector 499 shape: (768,)
# Vector 500 shape: (768,)
# Vector 501 shape: (768,)
# Vector 502 shape: (768,)
# Vector 503 shape: (768,)
# Vector 504 shape: (768,)
# Vector 505 shape: (768,)
# Vector 506 shape: (768,)
# Vector 507 shape: (768,)
# Vector 508 shape: (768,)
# Vector 509 shape: (768,)
# Vector 510 shape: (768,)
# Vector 511 shape: (768,)
# Vector 512 shape: (768,)
# Vector 513 shape: (768,)
# Vector 514 shape: (768,)
# Vector 515 shape: (768,)
# Vector 516 shape: (768,)
# Vector 517 shape: (768,)
# Vector 518 shape: (768,)
# Vector 519 shape: (768,)
# Vector 520 shape: (768,)
# Vector 521 shape: (768,)
# Vector 522 shape: (768,)
# Vector 523 shape: (768,)
# Vector 524 shape: (768,)
# Vector 525 shape: (768,)
# Vector 526 shape: (768,)
# Vector 527 shape: (768,)
# Vector 528 shape: (768,)
# Vector 529 shape: (768,)
# Vector 530 shape: (768,)
# Vector 531 shape: (768,)
# Vector 532 shape: (768,)
# Vector 533 shape: (768,)
# Vector 534 shape: (768,)
# Vector 535 shape: (768,)
# Vector 536 shape: (768,)
# Vector 537 shape: (768,)
# Vector 538 shape: (768,)
# Vector 539 shape: (768,)
# Vector 540 shape: (768,)
# Vector 541 shape: (768,)
# Vector 542 shape: (768,)
# Vector 543 shape: (768,)
# Vector 544 shape: (768,)
# Vector 545 shape: (768,)
# Vector 546 shape: (768,)
# Vector 547 shape: (768,)
# Vector 548 shape: (768,)
# Vector 549 shape: (768,)
# Vector 550 shape: (768,)
# Vector 551 shape: (768,)
# Vector 552 shape: (768,)
# Vector 553 shape: (768,)
# Vector 554 shape: (768,)
# Vector 555 shape: (768,)
# Vector 556 shape: (768,)
# Vector 557 shape: (768,)
# Vector 558 shape: (768,)
# Vector 559 shape: (768,)
# Vector 560 shape: (768,)
# Vector 561 shape: (768,)
# Vector 562 shape: (768,)
# Vector 563 shape: (768,)
# Vector 564 shape: (768,)
# Vector 565 shape: (768,)
# Vector 566 shape: (768,)
# Vector 567 shape: (768,)
# Vector 568 shape: (768,)
# Vector 569 shape: (768,)
# Vector 570 shape: (768,)
# Vector 571 shape: (768,)
# Vector 572 shape: (768,)
# Vector 573 shape: (768,)
# Vector 574 shape: (768,)
# Vector 575 shape: (768,)
# Vector 576 shape: (768,)
# Vector 577 shape: (768,)
# Vector 578 shape: (768,)
# Vector 579 shape: (768,)
# Vector 580 shape: (768,)
# Vector 581 shape: (768,)
# Vector 582 shape: (768,)
# Vector 583 shape: (768,)
# Vector 584 shape: (768,)
# Vector 585 shape: (768,)
# Vector 586 shape: (768,)
# Vector 587 shape: (768,)
# Vector 588 shape: (768,)
# Vector 589 shape: (768,)
# Vector 590 shape: (768,)
# Vector 591 shape: (768,)
# Vector 592 shape: (768,)
# Vector 593 shape: (768,)
# Vector 594 shape: (768,)
# Vector 595 shape: (768,)
# Vector 596 shape: (768,)
# Vector 597 shape: (768,)
# Vector 598 shape: (768,)
# Vector 599 shape: (768,)
# Vector 600 shape: (768,)
# Vector 601 shape: (768,)
# Vector 602 shape: (768,)
# Vector 603 shape: (768,)
# Vector 604 shape: (768,)
# Vector 605 shape: (768,)
# Vector 606 shape: (768,)
# Vector 607 shape: (768,)
# Vector 608 shape: (768,)
# Vector 609 shape: (768,)
# Vector 610 shape: (768,)
# Vector 611 shape: (768,)
# Vector 612 shape: (768,)
# Vector 613 shape: (768,)
# Vector 614 shape: (768,)
# Vector 615 shape: (768,)
# Vector 616 shape: (768,)
# Vector 617 shape: (768,)
# Vector 618 shape: (768,)
# Vector 619 shape: (768,)
# Vector 620 shape: (768,)

# %%
import numpy as np

# book_vectors4 리스트를 NumPy 배열로 변환
book_vectors_matrix = np.array(book_vectors4)

# 결과 출력
print(book_vectors_matrix.shape)
# Out:
# (621, 768)

# %%
import numpy as np
import pickle

# NumPy 배열을 .npy 파일로 저장
book_vectors_matrix = np.array(book_vectors4)
np.save('song_vectors_matrix.npy', book_vectors_matrix)

# NumPy 배열을 pickle 파일로 저장
with open('song_vectors_matrix.pkl', 'wb') as f:
    pickle.dump(book_vectors_matrix, f)

print("NumPy 배열이 pickle 파일로 저장되었습니다.")
# Out:
# NumPy 배열이 pickle 파일로 저장되었습니다.
